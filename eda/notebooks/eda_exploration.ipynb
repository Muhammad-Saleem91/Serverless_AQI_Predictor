# %%
import pandas as pd
df_clean = pd.read_csv('C:/Users/msale/Desktop/aqi_predictor_10Pearls/aqi-weather-6-months-for-eda.csv',index_col= 0)

# %%
df_clean.columns
# Out:
# Index(['timestamp', 'pm10', 'pm2_5', 'carbon_monoxide', 'nitrogen_dioxide',
#        'sulphur_dioxide', 'ozone', 'us_aqi', 'temperature_2m',
#        'relative_humidity_2m', 'wind_speed_10m', 'surface_pressure'],
#       dtype='object')

# %%
df_clean['timestamp']
# Out:
# 0       2025-08-17 00:00:00
# 1       2025-08-17 01:00:00
# 2       2025-08-17 02:00:00
# 3       2025-08-17 03:00:00
# 4       2025-08-17 04:00:00
#                ...
# 4339    2026-02-13 19:00:00
# 4340    2026-02-13 20:00:00
# 4341    2026-02-13 21:00:00
# 4342    2026-02-13 22:00:00
# 4343    2026-02-13 23:00:00
# Name: timestamp, Length: 4344, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from ingestion.fetch_data import fetch_karachi_aqi_weather
#       2 from preprocessing.clean_data import clean_aqi_weather_data
#       4 df_raw = fetch_karachi_aqi_weather("2025-10-01", "2026-01-01")
#
# ModuleNotFoundError: No module named 'ingestion'

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_clean["us_aqi"], bins=40, kde=True)
plt.title("Distribution of AQI in Karachi")
plt.xlabel("US AQI")
plt.ylabel("Frequency")
plt.show()
